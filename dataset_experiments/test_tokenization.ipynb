# %%
from realchords.dataset.hooktheory_dataloader import HooktheoryDataset, get_dataloader
import json

dataset = HooktheoryDataset(
    split="train",
    model_type="decoder_only",
    max_len=512,
    cache_dir="data/cache/hooktheory"
)

item = dataset[0]
print("="*60)
print("Raw Cached Item:")
print("="*60)
raw_item = dataset.data[0] #JSONIndexer, reads first line of the JSONL file
